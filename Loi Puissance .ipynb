# %%
### importation
from random import randint
from random import uniform, seed
import sys
import numpy as np
import json
import datetime
import matplotlib.pyplot as plt
import os

### setting the work path 
path="/users/yoanrussac/desktop/ENSAE-Cours/2A/Stat_App"
os.chdir(path)

# %%
graph=json.load(open("undirected_graph.json")) ## importation of the data

# %%
len(graph) ### number of nodes in the new graph
# Out:
# 9696

# %%
h = [len(graph[key]) for key in graph.keys() if len(graph[key]) > 5] ## we keep the nodes which have at least 5 neighbors
h_2=[len(graph[key]) for key in graph.keys()] ## we keep everynodes

# %% [markdown]
# Illustration of the power law phenomenon

# %%
plt.hist(h_2,bins=50,range=(1,400))
plt.title("Power law for our Twitter Graph")
plt.show()
# Out:
# 8762
# 9696

# %%
h_log=np.log(h)

# %%
x=[]
y=[]
for i in set(h):
    x+=[np.log(i)]
    y+=[np.log(h.count(i))]

# %%
plt.plot(x[0:150], y[0:150], 'ro')
plt.axis([1.5, 5.5, -0.5, 6])
plt.title(" Log- Log représentation")
plt.show()

# %%
x=[]
y=[]
for i in set(h):
    x+=[i]
    y+=[np.log(h.count(i))]

len(y)
# Out:
# 394

# %%
plt.plot(x[0:150], y[0:150], 'ro')
plt.axis([0, 160, 0, 6])
plt.title("log(y)=f(x)")
plt.show()
